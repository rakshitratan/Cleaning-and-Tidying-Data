# %%
import pandas as pd

# %%
# Let us import data:
df = pd.read_csv("InternetUsersDataset.csv")

# %%
df.head()
# Out:
#   Country Name Country Code                   Indicator Name  Indicator Code  \
# 0        Aruba          ABW  Internet users (per 100 people)  IT.NET.USER.P2
# 1      Andorra          AND  Internet users (per 100 people)  IT.NET.USER.P2
# 2  Afghanistan          AFG  Internet users (per 100 people)  IT.NET.USER.P2
# 3       Angola          AGO  Internet users (per 100 people)  IT.NET.USER.P2
# 4      Albania          ALB  Internet users (per 100 people)  IT.NET.USER.P2
#
#    1960  1961  1962  1963  1964  1965  ...       2007   2008   2009  2010  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...  30.900000  52.00  58.00  62.0
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  70.870000  70.04  78.53  81.0
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.900000   1.84   3.55   4.0
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.700000   1.90   2.30   2.8
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...  15.036115  23.86  41.20  45.0
#
#    2011       2012  2013   2014       2015  2016
# ...

# %% [markdown]
# # A. Let us see different methods to find details about our dataset:

# %% [markdown]
# 1) This method prints information about a DataFrame including, the index dtype and column dtypes, non-null values and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 61 columns):
# Country Name      264 non-null object
# Country Code      264 non-null object
# Indicator Name    264 non-null object
# Indicator Code    264 non-null object
# 1960              7 non-null float64
# 1961              0 non-null float64
# 1962              0 non-null float64
# 1963              0 non-null float64
# 1964              0 non-null float64
# 1965              7 non-null float64
# 1966              0 non-null float64
# 1967              0 non-null float64
# 1968              0 non-null float64
# 1969              0 non-null float64
# 1970              7 non-null float64
# 1971              0 non-null float64
# 1972              0 non-null float64
# 1973              0 non-null float64
# 1974              0 non-null float64
# 1975              7 non-null float64
# 1976              7 non-null float64
# 1977              7 non-null float64
# ...

# %% [markdown]
# 2) This returns a Series with the data type of each column. The result's index is the original DataFrame's columns. Columns
# with mixed types are stored with the ``object`` dtype.This returns a Series with the data type of each column.
# The result's index is the original DataFrame's columns. Columns with mixed types are stored with the ``object`` dtype.

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
# 1961              float64
# 1962              float64
# 1963              float64
# 1964              float64
# 1965              float64
# 1966              float64
# 1967              float64
# 1968              float64
# 1969              float64
# 1970              float64
# 1971              float64
# 1972              float64
# 1973              float64
# 1974              float64
# 1975              float64
# 1976              float64
# 1977              float64
# 1978              float64
# 1979              float64
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
#                    ...
# 1987              float64
# 1988              float64
# 1989              float64
# 1990              float64
# ...

# %% [markdown]
# 3) Return a tuple representing the dimensionality of the DataFrame.
#
# A tuple is a sequence of immutable Python objects. Tuples are sequences, just like lists.
# The differences between tuples and lists are, the tuples cannot be changed unlike lists and
# tuples use parentheses, whereas lists use square brackets. Creating a tuple is as simple as
# putting different comma-separated values.

# %%
df.shape
# Out:
# (264, 61)

# %% [markdown]
# 4) Return a boolean same-sized object indicating if the values are NA.
# NA values, such as None or :attr:`numpy.NaN`, gets mapped to True values.
# Everything else gets mapped to False values. Characters such as empty strings ``''`` or :attr:`numpy.inf` are not considered NA values (unless you set ``pandas.options.mode.use_inf_as_na = True``).

# %%
df.isnull()
# Out:
#      Country Name  Country Code  Indicator Name  Indicator Code   1960  1961  \
# 0           False         False           False           False   True  True
# 1           False         False           False           False   True  True
# 2           False         False           False           False   True  True
# 3           False         False           False           False   True  True
# 4           False         False           False           False   True  True
# 5           False         False           False           False   True  True
# 6           False         False           False           False   True  True
# 7           False         False           False           False   True  True
# 8           False         False           False           False   True  True
# 9           False         False           False           False   True  True
# 10          False         False           False           False   True  True
# ...

# %% [markdown]
# 5) Returns the sum of all the True vales when we run isnull function on a dataset

# %%
df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              257
# 1961              264
# 1962              264
# 1963              264
# 1964              264
# 1965              257
# 1966              264
# 1967              264
# 1968              264
# 1969              264
# 1970              257
# 1971              264
# 1972              264
# 1973              264
# 1974              264
# 1975              257
# 1976              257
# 1977              257
# 1978              257
# 1979              257
# 1980              257
# 1981              257
# 1982              257
# 1983              257
# 1984              257
# 1985              257
#                  ...
# 1987              257
# 1988              257
# 1989              256
# 1990               10
# 1991              219
# 1992              202
# 1993              176
# 1994              144
# 1995               93
# 1996               50
# ...

# %% [markdown]
# 6) Return a Numpy representation of the DataFrame.

# %%
df.values
# Out:
# array([['Aruba', 'ABW', 'Internet users (per 100 people)', ..., 83.78,
#         88.66122693, nan],
#        ['Andorra', 'AND', 'Internet users (per 100 people)', ..., 95.9,
#         96.91, nan],
#        ['Afghanistan', 'AFG', 'Internet users (per 100 people)', ...,
#         7.0, 8.26, nan],
#        ...,
#        ['Congo, Dem. Rep.', 'COD', 'Internet users (per 100 people)',
#         ..., 3.0, 3.799999507, nan],
#        ['Zambia', 'ZMB', 'Internet users (per 100 people)', ..., 19.0,
#         21.0, nan],
#        ['Zimbabwe', 'ZWE', 'Internet users (per 100 people)', ..., 16.3,
#         16.36, nan]], dtype=object)

# %% [markdown]
# 7) Count non-NA cells for each column or row

# %%
df.count()
# Out:
# Country Name      264
# Country Code      264
# Indicator Name    264
# Indicator Code    264
# 1960                7
# 1961                0
# 1962                0
# 1963                0
# 1964                0
# 1965                7
# 1966                0
# 1967                0
# 1968                0
# 1969                0
# 1970                7
# 1971                0
# 1972                0
# 1973                0
# 1974                0
# 1975                7
# 1976                7
# 1977                7
# 1978                7
# 1979                7
# 1980                7
# 1981                7
# 1982                7
# 1983                7
# 1984                7
# 1985                7
#                  ...
# 1987                7
# 1988                7
# 1989                8
# 1990              254
# 1991               45
# 1992               62
# 1993               88
# 1994              120
# 1995              171
# 1996              214
# ...

# %% [markdown]
# 8) Returns the number of non-NA value in the selected columns:

# %%
df['Country Name'].value_counts()
# Out:
# Israel                                               1
# Uganda                                               1
# IBRD only                                            1
# Kenya                                                1
# New Zealand                                          1
# Hungary                                              1
# Dominica                                             1
# Italy                                                1
# Jordan                                               1
# Bahamas, The                                         1
# Iceland                                              1
# Australia                                            1
# Greenland                                            1
# Comoros                                              1
# Djibouti                                             1
# Bolivia                                              1
# Middle East & North Africa                           1
# ...

# %% [markdown]
# 9) Counting number of Zero values

# %%
print ((df==0).sum())
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                7
# 1961                0
# 1962                0
# 1963                0
# 1964                0
# 1965                7
# 1966                0
# 1967                0
# 1968                0
# 1969                0
# 1970                7
# 1971                0
# 1972                0
# 1973                0
# 1974                0
# 1975                7
# 1976                7
# 1977                7
# 1978                7
# 1979                7
# 1980                7
# 1981                7
# 1982                7
# 1983                7
# 1984                7
# 1985                7
#                  ...
# 1987                7
# 1988                7
# 1989                8
# 1990              224
# 1991                8
# 1992                7
# 1993               10
# 1994               11
# 1995               11
# 1996                5
# ...

# %% [markdown]
# 10) Defines type of the dataframe

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Visualising Missing Values:

# %%
import missingno as msno
import matplotlib

# %%
missingdata_df= df.columns[df.isnull().any()].tolist()

# %%
msno.bar(df[missingdata_df], color= "orange", log=True, figsize=(30,18))

# %% [markdown]
# # Dealing with missing values

# %% [markdown]
# Using different methods to find details about our dataset we know how many NA/missing/0 values we have.

# %%
df.isna().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              257
# 1961              264
# 1962              264
# 1963              264
# 1964              264
# 1965              257
# 1966              264
# 1967              264
# 1968              264
# 1969              264
# 1970              257
# 1971              264
# 1972              264
# 1973              264
# 1974              264
# 1975              257
# 1976              257
# 1977              257
# 1978              257
# 1979              257
# 1980              257
# 1981              257
# 1982              257
# 1983              257
# 1984              257
# 1985              257
#                  ...
# 1987              257
# 1988              257
# 1989              256
# 1990               10
# 1991              219
# 1992              202
# 1993              176
# 1994              144
# 1995               93
# 1996               50
# ...

# %% [markdown]
# 1) Dropping the NaN values
#
# Using "Dropna" function drops all the missing values in rows by default.

# %%
drop_NaN = df.dropna()

# %%
drop_NaN.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
# 1961              0
# 1962              0
# 1963              0
# 1964              0
# 1965              0
# 1966              0
# 1967              0
# 1968              0
# 1969              0
# 1970              0
# 1971              0
# 1972              0
# 1973              0
# 1974              0
# 1975              0
# 1976              0
# 1977              0
# 1978              0
# 1979              0
# 1980              0
# 1981              0
# 1982              0
# 1983              0
# 1984              0
# 1985              0
#                  ..
# 1987              0
# 1988              0
# 1989              0
# 1990              0
# 1991              0
# 1992              0
# 1993              0
# 1994              0
# 1995              0
# 1996              0
# 1997              0
# 1998              0
# 1999              0
# 2000              0
# ...

# %%
df.shape
# Out:
# (264, 61)

# %%
drop_NaN.shape
# Out:
# (0, 61)

# %%
drop_NaN
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
# Index: []
#
# [0 rows x 61 columns]

# %% [markdown]
# Dropping 'NaN' values in columns using the 'dropna' function:

# %%
drop_nan = df.dropna(axis=1)

# %%
drop_nan.shape
# Out:
# (264, 4)

# %% [markdown]
# 2) Using 'Fillna' function

# %% [markdown]
# Filllig the NaN values with '0' using 'fillna'" function:

# %%
fill_NaN = df.fillna(0)
fill_NaN.count()
# Out:
# Country Name      264
# Country Code      264
# Indicator Name    264
# Indicator Code    264
# 1960              264
# 1961              264
# 1962              264
# 1963              264
# 1964              264
# 1965              264
# 1966              264
# 1967              264
# 1968              264
# 1969              264
# 1970              264
# 1971              264
# 1972              264
# 1973              264
# 1974              264
# 1975              264
# 1976              264
# 1977              264
# 1978              264
# 1979              264
# 1980              264
# 1981              264
# 1982              264
# 1983              264
# 1984              264
# 1985              264
#                  ...
# 1987              264
# 1988              264
# 1989              264
# 1990              264
# 1991              264
# 1992              264
# 1993              264
# 1994              264
# 1995              264
# 1996              264
# ...

# %%
df
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                              Andorra          AND
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %% [markdown]
# Using numpy to replace all "0" values with NaN.

# %%
import numpy as np

# %%
df_all_NaN = df.replace(0, np.nan)

# %%
print ((df_all_NaN==0).sum())
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
# 1961              0
# 1962              0
# 1963              0
# 1964              0
# 1965              0
# 1966              0
# 1967              0
# 1968              0
# 1969              0
# 1970              0
# 1971              0
# 1972              0
# 1973              0
# 1974              0
# 1975              0
# 1976              0
# 1977              0
# 1978              0
# 1979              0
# 1980              0
# 1981              0
# 1982              0
# 1983              0
# 1984              0
# 1985              0
#                  ..
# 1987              0
# 1988              0
# 1989              0
# 1990              0
# 1991              0
# 1992              0
# 1993              0
# 1994              0
# 1995              0
# 1996              0
# 1997              0
# 1998              0
# 1999              0
# 2000              0
# ...
